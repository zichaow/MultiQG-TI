# %%
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
s_model = [0.672,	0.789,	0.786,	0.731]
m_model = [0.721,	0.828,	0.824,	0.758]
l_model = [0.747,	0.846,	0.844,	0.773]

bleu4 = np.array([0.672, 0.721, 0.747])
meteor = np.array([0.789, 0.828, 0.846])
rouge = np.array([0.786, 0.824, 0.844])
bleurt = np.array([0.731, 0.758, 0.773])

# %%
sns.set_theme()

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams["figure.figsize"] = [12, 6]
plt.rcParams["figure.autolayout"] = True

x = np.array([0,2,4])
plt.bar(x + -0.5, bleu4, 0.25, label='BLEU')
plt.bar(x + -0.25, meteor, 0.25, label='METEOR')
plt.bar(x + 0, rouge, 0.25, label='ROUGE')
plt.bar(x + 0.25, bleurt, 0.25, label='BLEURT')
yilm = plt.ylim(0.65, 0.85)
yticks = plt.yticks(fontsize=25)
xticks = plt.xticks(x, ['Small', 'Medium', 'Large'], fontsize=25)
xlab = plt.xlabel('Model Size', fontsize=30)
legend = plt.legend(fontsize=21, loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=5)

plt.savefig('fig_ablation_modelsize.pdf', bbox_inches='tight')
